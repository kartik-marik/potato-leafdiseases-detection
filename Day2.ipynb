# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik-marik/potato-leafdiseases-detection/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Augmentation**
#
# *   In CNN out of box are not scale or rotation invariant which means lets say you are trying to classify roses and tulifs and the training set contains the proper clear image of these two flowers.after training in cnn when you supply a rotated image of rose or tulifs for classification so in this scenerio, cnn might not perform better. and to handle this problem we use a technique called data augmentation.
# *   In DataAugmentation from our existing training samples we try to generate new samples.
# ![data augmentation.PNG](data:image/png;base64,...)

# %% [markdown]
# **TF Dataset**
#
#
# *   The tf.data.Dataset API in TensorFlow is a powerful tool for loading, preprocessing, and batching data for machine learning models.However, it can be difficult to use when working with large datasets, as it can require a lot of memory and CPU resources.
# *   Google Colab is a free cloud-based platform that provides users with access to a GPU-accelerated environment for machine learning tasks.This makes it an ideal platform for working with large datasets, as the GPU can help to speed up the data loading and processing times.
# *   One way to use Google Colab with large datasets is to use the tfds.core.DatasetInfo class.This class provides a number of methods for loading and preprocessing data, including the ability to load data from a variety of sources, such as CSV files, TFRecords files, and Cloud Storage.
# *   Once the data has been loaded, it can be preprocessed using the tfds.core.DatasetInfo class's preprocessing methods.These methods include methods for converting data to a variety of formats, such as NumPy arrays, Pandas DataFrames, and Tensors.
# *   The preprocessed data can then be batched using the tfds.core.DatasetInfo class's batch() method.This method batches the data into a fixed-size number of samples, which can help to speed up the training process.
#
# *   Another way to use Google Colab with large datasets is to use the tfds.core.Dataset class.This class provides a number of methods for loading and preprocessing data, including the ability to load data from a variety of sources, such as CSV files, TFRecords files, and Cloud Storage.
# *   Once the data has been loaded, it can be preprocessed using the tfds.core.Dataset class's preprocessing methods. These methods include methods for converting data to a variety of formats, such as NumPy arrays, Pandas DataFrames, and Tensors.The preprocessed data can then be batched using the tfds.core.Dataset class's batch() method. This method batches the data into a fixed-size number of samples, which can help to speed up the training process.
# Finally, the data can be trained using the tf.keras.Model class. This class provides a number of methods for training models, including the ability to train models using a variety of optimizers, such as SGD, Adam, and RMSProp.
# The trained model can then be used to make predictions on new data.
